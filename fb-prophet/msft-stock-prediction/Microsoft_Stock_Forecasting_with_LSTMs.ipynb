# %%
# dataset @ https://finance.yahoo.com/quote/MSFT/history/

# If you want the exact same dataset as the YouTube video,
# use this link: https://drive.google.com/file/d/1WLm1AEYgU28Nk4lY4zNkGPSctdImbhJI/view?usp=sharing

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060163
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062311
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063386
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061774
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060700
# ...          ...         ...         ...         ...         ...         ...
# 9566  2024-02-28  408.179993  409.299988  405.320007  407.720001  407.720001
# 9567  2024-02-29  408.640015  414.200012  405.920013  413.640015  413.640015
# 9568  2024-03-01  411.269989  415.869995  410.880005  415.500000  415.500000
# 9569  2024-03-04  413.440002  417.350006  412.320007  414.920013  414.920013
# 9570  2024-03-05  413.959991  414.250000  400.640015  402.649994  402.649994
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9566    13183100
# 9567    31947300
# 9568    17800300
# 9569    17596000
# 9570    26919200
#
# [9571 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9566  2024-02-28  407.720001
# 9567  2024-02-29  413.640015
# 9568  2024-03-01  415.500000
# 9569  2024-03-04  414.920013
# 9570  2024-03-05  402.649994
#
# [9571 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9566    2024-02-28
# 9567    2024-02-29
# 9568    2024-03-01
# 9569    2024-03-04
# 9570    2024-03-05
# Name: Date, Length: 9571, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9566  2024-02-28  407.720001
# 9567  2024-02-29  413.640015
# 9568  2024-03-01  415.500000
# 9569  2024-03-04  414.920013
# 9570  2024-03-05  402.649994
#
# [9571 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\jnopa\AppData\Local\Temp\ipykernel_10064\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9566   2024-02-28
# 9567   2024-02-29
# 9568   2024-03-01
# 9569   2024-03-04
# 9570   2024-03-05
# Name: Date, Length: 9571, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-02-28  407.720001
# 2024-02-29  413.640015
# 2024-03-01  415.500000
# 2024-03-04  414.920013
# 2024-03-05  402.649994
#
# [9571 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '1986-03-18',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1986-03-18    0.097222    0.100694    0.102431    0.099826
# 1     1986-03-19    0.100694    0.102431    0.099826    0.098090
# 2     1986-03-20    0.102431    0.099826    0.098090    0.095486
# 3     1986-03-21    0.099826    0.098090    0.095486    0.092882
# 4     1986-03-24    0.098090    0.095486    0.092882    0.090278
# ...          ...         ...         ...         ...         ...
# 9074  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 9075  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 9076  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 9077  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 9078  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [9079 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
# split the dataset into dates for training, testing and validation
q_80 = int(len(dates) * .8) 
q_90 = int(len(dates) * .9)

# each variable corresponds to a range from the q_80 to q_90
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# WARNING:tensorflow:From d:\DEV WORK\Data Science Library\ML-For-Beginners\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From d:\DEV WORK\Data Science Library\ML-For-Beginners\.venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/100
# WARNING:tensorflow:From d:\DEV WORK\Data Science Library\ML-For-Beginners\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\DEV WORK\Data Science Library\ML-For-Beginners\.venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 4s 123ms/step - loss: 84742.2969 - mean_absolute_error: 289.3638 - val_loss: 92442.8672 - val_mean_absolute_error: 303.9571
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84523.8125 - mean_absolute_error: 288.9872 - val_loss: 92245.8672 - val_mean_absolute_error: 303.6328
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84338.4062 - mean_absolute_error: 288.6661 - val_loss: 92035.9609 - val_mean_absolute_error: 303.2870
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 84121.1172 - mean_absolute_error: 288.2901 - val_loss: 91781.8984 - val_mean_absolute_error: 302.8678
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83864.9453 - mean_absolute_error: 287.8447 - val_loss: 91476.1719 - val_mean_absolute_error: 302.3627
# Epoch 6/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83536.0391 - mean_absolute_error: 287.2717 - val_loss: 91058.7812 - val_mean_absolute_error: 301.6717
# Epoch 7/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83088.7578 - mean_absolute_error: 286.4937 - val_loss: 90478.8828 - val_mean_absolute_error: 300.7090
# Epoch 8/100
# 7/7 [==============================] - 0s 8ms/step - loss: 82446.9297 - mean_absolute_error: 285.3692 - val_loss: 89668.6328 - val_mean_absolute_error: 299.3587
# Epoch 9/100
# 7/7 [==============================] - 0s 8ms/step - loss: 81585.2500 - mean_absolute_error: 283.8564 - val_loss: 88544.2109 - val_mean_absolute_error: 297.4748
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80378.7031 - mean_absolute_error: 281.7233 - val_loss: 87130.4219 - val_mean_absolute_error: 295.0889
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 79022.2266 - mean_absolute_error: 279.3105 - val_loss: 85570.4766 - val_mean_absolute_error: 292.4336
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 77228.1016 - mean_absolute_error: 276.0804 - val_loss: 83135.8203 - val_mean_absolute_error: 288.2409
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74754.7188 - mean_absolute_error: 271.5515 - val_loss: 80273.1484 - val_mean_absolute_error: 283.2316
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 71899.9141 - mean_absolute_error: 266.2287 - val_loss: 76808.9766 - val_mean_absolute_error: 277.0485
# Epoch 15/100
# 7/7 [==============================] - 0s 14ms/step - loss: 68004.3047 - mean_absolute_error: 258.8499 - val_loss: 71954.0469 - val_mean_absolute_error: 268.1438
# Epoch 16/100
# 7/7 [==============================] - 0s 17ms/step - loss: 63445.3984 - mean_absolute_error: 249.8731 - val_loss: 67119.7266 - val_mean_absolute_error: 258.9724
# Epoch 17/100
# 7/7 [==============================] - 0s 9ms/step - loss: 58623.1641 - mean_absolute_error: 239.9377 - val_loss: 61138.6797 - val_mean_absolute_error: 247.1547
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 52626.1250 - mean_absolute_error: 227.1313 - val_loss: 54735.6758 - val_mean_absolute_error: 233.8431
# Epoch 19/100
# 7/7 [==============================] - 0s 14ms/step - loss: 46579.1133 - mean_absolute_error: 213.3932 - val_loss: 47683.2461 - val_mean_absolute_error: 218.2429
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 39643.2305 - mean_absolute_error: 196.4512 - val_loss: 40233.5391 - val_mean_absolute_error: 200.4507
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 32836.1484 - mean_absolute_error: 178.3437 - val_loss: 32508.9609 - val_mean_absolute_error: 180.1553
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 25845.5020 - mean_absolute_error: 157.3730 - val_loss: 25453.8926 - val_mean_absolute_error: 159.3766
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 19619.5605 - mean_absolute_error: 135.9725 - val_loss: 18350.7344 - val_mean_absolute_error: 135.2668
# Epoch 24/100
# 7/7 [==============================] - 0s 11ms/step - loss: 13233.1357 - mean_absolute_error: 110.2540 - val_loss: 12199.6279 - val_mean_absolute_error: 110.2117
# Epoch 25/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8515.5586 - mean_absolute_error: 86.4511 - val_loss: 7487.9121 - val_mean_absolute_error: 86.2250
# Epoch 26/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4942.7227 - mean_absolute_error: 62.9690 - val_loss: 4204.7261 - val_mean_absolute_error: 64.4324
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2772.6726 - mean_absolute_error: 43.0423 - val_loss: 1920.9967 - val_mean_absolute_error: 43.2211
# Epoch 28/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1513.4252 - mean_absolute_error: 32.1820 - val_loss: 854.7910 - val_mean_absolute_error: 28.3166
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1114.6794 - mean_absolute_error: 28.0764 - val_loss: 373.2131 - val_mean_absolute_error: 17.8955
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1016.4696 - mean_absolute_error: 27.0346 - val_loss: 210.9878 - val_mean_absolute_error: 12.8229
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1022.2687 - mean_absolute_error: 27.0041 - val_loss: 166.1443 - val_mean_absolute_error: 11.0453
# Epoch 32/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1027.8391 - mean_absolute_error: 27.0457 - val_loss: 166.9673 - val_mean_absolute_error: 11.0808
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1026.1294 - mean_absolute_error: 27.0368 - val_loss: 187.8043 - val_mean_absolute_error: 11.9409
# Epoch 34/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1016.8920 - mean_absolute_error: 26.9519 - val_loss: 220.6673 - val_mean_absolute_error: 13.1718
# Epoch 35/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1013.1348 - mean_absolute_error: 26.9265 - val_loss: 258.0427 - val_mean_absolute_error: 14.4327
# Epoch 36/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.1432 - mean_absolute_error: 26.8519 - val_loss: 279.5180 - val_mean_absolute_error: 15.1054
# Epoch 37/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1009.7665 - mean_absolute_error: 26.8679 - val_loss: 297.4965 - val_mean_absolute_error: 15.6443
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.4254 - mean_absolute_error: 26.8762 - val_loss: 308.9191 - val_mean_absolute_error: 15.9986
# Epoch 39/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1012.8176 - mean_absolute_error: 26.9097 - val_loss: 310.8302 - val_mean_absolute_error: 16.0582
# Epoch 40/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1010.5983 - mean_absolute_error: 26.8592 - val_loss: 288.6014 - val_mean_absolute_error: 15.3803
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1010.2111 - mean_absolute_error: 26.8662 - val_loss: 283.5192 - val_mean_absolute_error: 15.2272
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1009.2464 - mean_absolute_error: 26.8561 - val_loss: 267.0334 - val_mean_absolute_error: 14.7185
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1010.1614 - mean_absolute_error: 26.8676 - val_loss: 252.3588 - val_mean_absolute_error: 14.2489
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.1929 - mean_absolute_error: 26.8691 - val_loss: 256.8462 - val_mean_absolute_error: 14.3943
# Epoch 45/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1009.8548 - mean_absolute_error: 26.8637 - val_loss: 270.3097 - val_mean_absolute_error: 14.8211
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1008.8284 - mean_absolute_error: 26.8492 - val_loss: 276.6712 - val_mean_absolute_error: 15.0215
# Epoch 47/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1000.0703 - mean_absolute_error: 26.7428 - val_loss: 292.2516 - val_mean_absolute_error: 15.4986
# Epoch 48/100
# 7/7 [==============================] - 0s 14ms/step - loss: 994.0511 - mean_absolute_error: 26.6355 - val_loss: 253.2003 - val_mean_absolute_error: 14.2884
# Epoch 49/100
# 7/7 [==============================] - 0s 15ms/step - loss: 980.9690 - mean_absolute_error: 26.4528 - val_loss: 327.6475 - val_mean_absolute_error: 16.6299
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 950.4880 - mean_absolute_error: 26.0359 - val_loss: 248.1661 - val_mean_absolute_error: 14.1478
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 952.6596 - mean_absolute_error: 26.0390 - val_loss: 284.1980 - val_mean_absolute_error: 15.2994
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 924.9158 - mean_absolute_error: 25.6971 - val_loss: 315.6024 - val_mean_absolute_error: 16.3146
# Epoch 53/100
# 7/7 [==============================] - 0s 11ms/step - loss: 881.6744 - mean_absolute_error: 25.0256 - val_loss: 275.0949 - val_mean_absolute_error: 15.0507
# Epoch 54/100
# 7/7 [==============================] - 0s 11ms/step - loss: 838.5128 - mean_absolute_error: 24.1847 - val_loss: 179.4239 - val_mean_absolute_error: 11.7229
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 886.1940 - mean_absolute_error: 25.1131 - val_loss: 274.3950 - val_mean_absolute_error: 15.0443
# Epoch 56/100
# 7/7 [==============================] - 0s 9ms/step - loss: 838.5829 - mean_absolute_error: 24.4593 - val_loss: 253.8724 - val_mean_absolute_error: 14.4332
# Epoch 57/100
# 7/7 [==============================] - 0s 11ms/step - loss: 798.5842 - mean_absolute_error: 23.8181 - val_loss: 206.1870 - val_mean_absolute_error: 12.8232
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 765.8938 - mean_absolute_error: 23.2225 - val_loss: 217.3935 - val_mean_absolute_error: 13.2582
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 651.7066 - mean_absolute_error: 21.5117 - val_loss: 193.5034 - val_mean_absolute_error: 12.4293
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 577.6570 - mean_absolute_error: 20.0454 - val_loss: 167.9944 - val_mean_absolute_error: 11.4706
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 536.8926 - mean_absolute_error: 19.2169 - val_loss: 165.7380 - val_mean_absolute_error: 11.4197
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 477.9582 - mean_absolute_error: 18.1984 - val_loss: 331.5380 - val_mean_absolute_error: 17.1902
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 463.4097 - mean_absolute_error: 17.8723 - val_loss: 161.7204 - val_mean_absolute_error: 11.3159
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 407.3410 - mean_absolute_error: 16.6565 - val_loss: 81.0365 - val_mean_absolute_error: 7.4006
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 353.9773 - mean_absolute_error: 15.3684 - val_loss: 41.6622 - val_mean_absolute_error: 5.1790
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 330.3328 - mean_absolute_error: 14.9108 - val_loss: 41.5462 - val_mean_absolute_error: 5.5502
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 351.7010 - mean_absolute_error: 15.9453 - val_loss: 54.9342 - val_mean_absolute_error: 5.9423
# Epoch 68/100
# 7/7 [==============================] - 0s 9ms/step - loss: 266.9683 - mean_absolute_error: 13.6210 - val_loss: 137.0719 - val_mean_absolute_error: 10.3268
# Epoch 69/100
# 7/7 [==============================] - 0s 8ms/step - loss: 212.2909 - mean_absolute_error: 11.9154 - val_loss: 74.2767 - val_mean_absolute_error: 7.1143
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 175.3654 - mean_absolute_error: 10.6032 - val_loss: 47.4854 - val_mean_absolute_error: 5.6159
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 158.4569 - mean_absolute_error: 10.1115 - val_loss: 49.2965 - val_mean_absolute_error: 5.7446
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 130.3588 - mean_absolute_error: 8.8394 - val_loss: 65.3227 - val_mean_absolute_error: 6.7183
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 114.2236 - mean_absolute_error: 8.3246 - val_loss: 37.1563 - val_mean_absolute_error: 5.2038
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 89.9308 - mean_absolute_error: 7.0564 - val_loss: 39.0379 - val_mean_absolute_error: 5.1115
# Epoch 75/100
# 7/7 [==============================] - 0s 14ms/step - loss: 82.8703 - mean_absolute_error: 7.1887 - val_loss: 45.1313 - val_mean_absolute_error: 5.3901
# Epoch 76/100
# 7/7 [==============================] - 0s 11ms/step - loss: 76.3214 - mean_absolute_error: 6.9048 - val_loss: 34.4301 - val_mean_absolute_error: 4.8665
# Epoch 77/100
# 7/7 [==============================] - 0s 10ms/step - loss: 56.8084 - mean_absolute_error: 5.7400 - val_loss: 34.3789 - val_mean_absolute_error: 5.0646
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 53.7549 - mean_absolute_error: 5.5942 - val_loss: 33.3444 - val_mean_absolute_error: 4.9966
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 50.9853 - mean_absolute_error: 5.6920 - val_loss: 35.9354 - val_mean_absolute_error: 4.9167
# Epoch 80/100
# 7/7 [==============================] - 0s 11ms/step - loss: 40.8537 - mean_absolute_error: 4.9265 - val_loss: 34.8719 - val_mean_absolute_error: 4.8829
# Epoch 81/100
# 7/7 [==============================] - 0s 11ms/step - loss: 36.6144 - mean_absolute_error: 4.7609 - val_loss: 31.7720 - val_mean_absolute_error: 4.8194
# Epoch 82/100
# 7/7 [==============================] - 0s 13ms/step - loss: 44.7055 - mean_absolute_error: 5.3622 - val_loss: 35.9406 - val_mean_absolute_error: 5.1397
# Epoch 83/100
# 7/7 [==============================] - 0s 12ms/step - loss: 46.7390 - mean_absolute_error: 5.5612 - val_loss: 32.2164 - val_mean_absolute_error: 4.8578
# Epoch 84/100
# 7/7 [==============================] - 0s 13ms/step - loss: 48.8026 - mean_absolute_error: 5.7019 - val_loss: 32.0829 - val_mean_absolute_error: 4.8133
# Epoch 85/100
# 7/7 [==============================] - 0s 12ms/step - loss: 38.0214 - mean_absolute_error: 4.9384 - val_loss: 42.2639 - val_mean_absolute_error: 5.1860
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 29.5546 - mean_absolute_error: 4.3379 - val_loss: 38.8849 - val_mean_absolute_error: 4.9974
# Epoch 87/100
# 7/7 [==============================] - 0s 13ms/step - loss: 28.1506 - mean_absolute_error: 4.0698 - val_loss: 68.4485 - val_mean_absolute_error: 6.5942
# Epoch 88/100
# 7/7 [==============================] - 0s 12ms/step - loss: 32.2973 - mean_absolute_error: 4.5443 - val_loss: 61.5375 - val_mean_absolute_error: 6.1873
# Epoch 89/100
# 7/7 [==============================] - 0s 21ms/step - loss: 28.5555 - mean_absolute_error: 4.1722 - val_loss: 65.4094 - val_mean_absolute_error: 6.4070
# Epoch 90/100
# 7/7 [==============================] - 0s 17ms/step - loss: 31.2394 - mean_absolute_error: 4.5117 - val_loss: 59.4019 - val_mean_absolute_error: 6.0685
# Epoch 91/100
# 7/7 [==============================] - 0s 16ms/step - loss: 28.0393 - mean_absolute_error: 4.2457 - val_loss: 41.6077 - val_mean_absolute_error: 5.1695
# Epoch 92/100
# 7/7 [==============================] - 0s 15ms/step - loss: 28.7440 - mean_absolute_error: 4.1830 - val_loss: 38.2584 - val_mean_absolute_error: 4.9549
# Epoch 93/100
# 7/7 [==============================] - 0s 13ms/step - loss: 26.4845 - mean_absolute_error: 4.0586 - val_loss: 32.8507 - val_mean_absolute_error: 4.8058
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 23.8893 - mean_absolute_error: 3.8664 - val_loss: 69.2014 - val_mean_absolute_error: 6.6231
# Epoch 95/100
# 7/7 [==============================] - 0s 14ms/step - loss: 29.1009 - mean_absolute_error: 4.3040 - val_loss: 63.3072 - val_mean_absolute_error: 6.2632
# Epoch 96/100
# 7/7 [==============================] - 0s 16ms/step - loss: 23.9934 - mean_absolute_error: 3.9396 - val_loss: 39.7963 - val_mean_absolute_error: 5.0498
# Epoch 97/100
# 7/7 [==============================] - 0s 26ms/step - loss: 22.8578 - mean_absolute_error: 3.7695 - val_loss: 40.6072 - val_mean_absolute_error: 5.1111
# Epoch 98/100
# 7/7 [==============================] - 0s 13ms/step - loss: 22.1603 - mean_absolute_error: 3.7176 - val_loss: 33.7721 - val_mean_absolute_error: 4.8124
# Epoch 99/100
# 7/7 [==============================] - 0s 12ms/step - loss: 22.6409 - mean_absolute_error: 3.7539 - val_loss: 46.8084 - val_mean_absolute_error: 5.5058
# Epoch 100/100
# 7/7 [==============================] - 0s 14ms/step - loss: 21.8100 - mean_absolute_error: 3.7064 - val_loss: 38.9053 - val_mean_absolute_error: 4.9866

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 40ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
